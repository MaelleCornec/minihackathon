# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/Vehicles.txt', sep='\t')
data.head(10)
# Out:
#      AccidentId VehicleId Direction          Category  PassengerNumber  \
# 0  201800000001       A01   Unknown         Car<=3.5T                0
# 1  201800000001       B01   Unknown         Car<=3.5T                0
# 2  201800000002       A01   Unknown         Car<=3.5T                0
# 3  201800000003       A01   Unknown  Motorbike>125cm3                0
# 4  201800000003       B01   Unknown         Car<=3.5T                0
# 5  201800000003       C01   Unknown         Car<=3.5T                0
# 6  201800000004       A01   Unknown         Car<=3.5T                0
# 7  201800000004       B01   Unknown           Bicycle                0
# 8  201800000005       A01   Unknown             Moped                0
# 9  201800000005       B01   Unknown         Car<=3.5T                0
#
#        FixedObstacle MobileObstacle ImpactPoint           Maneuver
# 0               None        Vehicle  RightFront         TurnToLeft
# 1               None        Vehicle   LeftFront  NoDirectionChange
# 2               None     Pedestrian        None  NoDirectionChange
# 3  StationaryVehicle        Vehicle       Front  NoDirectionChange
# 4               None        Vehicle    LeftSide         TurnToLeft
# 5               None           None   RightSide             Parked
# 6               None          Other  RightFront          Avoidance
# 7               None        Vehicle    LeftSide               None
# 8               None        Vehicle  RightFront           PassLeft
# 9               None        Vehicle   LeftFront               Park

# %%
data.columns.values
# Out:
# array(['AccidentId', 'VehicleId', 'Direction', 'Category',
#        'PassengerNumber', 'FixedObstacle', 'MobileObstacle',
#        'ImpactPoint', 'Maneuver'], dtype=object)

# %%
data.shape
# Out:
# (98876, 9)

# %%
data.describe()
# Out:
#          AccidentId  PassengerNumber
# count  9.887600e+04     98876.000000
# mean   2.018000e+11         0.148145
# std    1.674375e+04         4.029273
# min    2.018000e+11         0.000000
# 25%    2.018000e+11         0.000000
# 50%    2.018000e+11         0.000000
# 75%    2.018000e+11         0.000000
# max    2.018001e+11       900.000000

# %%
data.describe(exclude=[np.number])
# Out:
#        VehicleId   Direction   Category FixedObstacle MobileObstacle  \
# count      98876       98744      98876         98687          98741
# unique        26           3         24            17              7
# top          A01  Increasing  Car<=3.5T          None        Vehicle
# freq       56736       47358      60384         84571          69438
#
#        ImpactPoint           Maneuver
# count        98743              98744
# unique          10                 25
# top          Front  NoDirectionChange
# freq         35421              39560

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98876 entries, 0 to 98875
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AccidentId       98876 non-null  int64
#  1   VehicleId        98876 non-null  object
#  2   Direction        98744 non-null  object
#  3   Category         98876 non-null  object
#  4   PassengerNumber  98876 non-null  int64
#  5   FixedObstacle    98687 non-null  object
#  6   MobileObstacle   98741 non-null  object
#  7   ImpactPoint      98743 non-null  object
#  8   Maneuver         98744 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 6.8+ MB

# %%
categorical_data = data.select_dtypes(include="object")

# Réalisation de graphe grâce sns.countplot pour toutes les variables catégorielles
for i in categorical_data.columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(y=i, data=categorical_data)
    plt.show()
